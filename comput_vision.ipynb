# %% [markdown]
# <a href="https://colab.research.google.com/github/Adnan4555/ADNAN-4555/blob/COMPUTER-VISION/comput_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/images (1).jpeg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=276x183>

# %%
#resizing the image
resized_image = cv2.resize(image,(400,300))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
#converting to grey scale
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=276x183>

# %%
image.shape
# Out:
# (183, 276, 3)

# %%
#tilting of image
(h,w) = image.shape[:2]
center = (w//2,h//2)
rotation_matrix = cv2.getRotationMatrix2D(center,45,1.0) #rotate 45 degree
rotated_image = cv2.warpAffine(image,rotation_matrix,(w,h))
cv2_imshow(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=276x183>

# %%
#croppimg of image
cropped_image = image[50:,100:]
cv2_imshow(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=176x133>

# %%
#flip the image
flipped_image = cv2.flip(image,1)
cv2_imshow(flipped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=276x183>

# %%
#flip the image
flipped_image = cv2.flip(image,-1)
cv2_imshow(flipped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=276x183>

# %%
#blurring of image
blurred_image = cv2.GaussianBlur(image,(3,3),0)
cv2_imshow(blurred_image)
# Out:
# <PIL.Image.Image image mode=RGB size=276x183>

# %%
#edge detection
edges = cv2.Canny(image,300,600)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=276x183>
