# %% [markdown]
# <a href="https://colab.research.google.com/github/Adnan4555/ADNAN-4555/blob/DATA-SCIENCE/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #define dictionary

# %%
datas = {
    "name" : ["alice","bob","charlie"],
    "age" : [25,30,35],
    "city" : ["london","paris","berlin"]
}

# %%
dict1 = pd.DataFrame(datas)

# %%
print(dict1)
# Out:
#       name  age    city
# 0    alice   25  london
# 1      bob   30   paris
# 2  charlie   35  berlin

# %% [markdown]
# #dataframe using list

# %%
data1  = [
    ["alice",25,"london"],
    ["bob",30,"paris"],
    ["charlie",35,"berlin"]
]

# %%
columns = ["name","age","city"]

# %%
list1 = pd.DataFrame(data1,columns = columns)

# %%
print(list1)
# Out:
#       name  age    city
# 0    alice   25  london
# 1      bob   30   paris
# 2  charlie   35  berlin

# %% [markdown]
# #creating the dataframe using specify column names

# %%
list2 = pd.DataFrame(data1,columns = ["name","age","city"])

# %%
print(list2)
# Out:
#       name  age    city
# 0    alice   25  london
# 1      bob   30   paris
# 2  charlie   35  berlin

# %% [markdown]
# #indexing the dataframe using .loc function

# %%
row_0 = list2.loc[0]

# %%
print(row_0)
# Out:
# name     alice
# age         25
# city    london
# Name: 0, dtype: object

# %% [markdown]
# #to access more rows (use extra square brackets)

# %%
rows_1 = list2.loc[[0,1]]

# %%
print(rows_1)
# Out:
#     name  age    city
# 0  alice   25  london
# 1    bob   30   paris

# %% [markdown]
# #accessing the columns

# %%
columns1 = list2.loc[:,"name"]

# %%
print(columns1)
# Out:
# 0      alice
# 1        bob
# 2    charlie
# Name: name, dtype: object

# %% [markdown]
# #accessing more columns

# %%
columns2 = list2.loc[:,["name","age"]]

# %%
print(columns2)
# Out:
#       name  age
# 0    alice   25
# 1      bob   30
# 2  charlie   35

# %% [markdown]
# #accessing the rows and columns

# %%
age1 = list2.loc[0,"age"]

# %%
print(age1)
# Out:
# 25

# %% [markdown]
# #accessing the first two rows

# %%
rows2 = list2.loc[0:1,["name","age"]]

# %%
print(rows2)
# Out:
#     name  age
# 0  alice   25
# 1    bob   30

# %% [markdown]
# #access a specifiv row by index : to access row by its intger position

# %%
row2 = list2.iloc[0]
print(row2)
# Out:
# name     alice
# age         25
# city    london
# Name: 0, dtype: object

# %%
rows3 = list2.iloc[0:2]
print(rows3)
# Out:
#     name  age    city
# 0  alice   25  london
# 1    bob   30   paris

# %%
all1 = list2.iloc[:,0]

# %%
print(all1)
# Out:
# 0      alice
# 1        bob
# 2    charlie
# Name: name, dtype: object

# %%
print(list2)
# Out:
#       name  age    city
# 0    alice   25  london
# 1      bob   30   paris
# 2  charlie   35  berlin

# %%
all2 = list2.iloc[:,0:2]
print(all2)
# Out:
#       name  age
# 0    alice   25
# 1      bob   30
# 2  charlie   35

# %% [markdown]
# #dataframe attributes

# %%
print(datas)
# Out:
# {'name': ['alice', 'bob', 'charlie'], 'age': [25, 30, 35], 'city': ['london', 'paris', 'berlin']}

# %%
print(dict1)
# Out:
#       name  age    city
# 0    alice   25  london
# 1      bob   30   paris
# 2  charlie   35  berlin

# %%
print(dict1.shape)
# Out:
# (3, 3)

# %%
print(dict1.columns)
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
print(dict1.dtypes)
# Out:
# name    object
# age      int64
# city    object
# dtype: object

# %%
print(dict1.values)
# Out:
# [['alice' 25 'london']
#  ['bob' 30 'paris']
#  ['charlie' 35 'berlin']]

# %%
a = dict1.ndim

# %%
print(a)
# Out:
# 2

# %%
s = dict1.size
print(s)
# Out:
# 9

# %% [markdown]
# #transpose

# %%
transpose = dict1.T
print(transpose)
# Out:
#            0      1        2
# name   alice    bob  charlie
# age       25     30       35
# city  london  paris   berlin

# %%
df = pd.read_csv('/content/train (1).csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.to_excel('train.xlsx')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #for information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])

# %%
s
# Out:
# a    0.029967
# b   -0.568716
# c   -0.895800
# d    0.790006
# e    1.060040
# dtype: float64

# %%
dict = {"b":2,"a":4,"v":5}
pd.Series(dict)
# Out:
# b    2
# a    4
# v    5
# dtype: int64

# %%
pd.Series(dict,index = ["a","b","v"])
# Out:
# a    4
# b    2
# v    5
# dtype: int64

# %%
dataframe1 = pd.DataFrame(
    {
        "A":["A0","A1","A2","A3"],
        "B":["B0","B1","B2","B3"],
        "C":["C0","C1","C2","C3"],
        "D":["D0","D1","D2","D3"]
    },
    index = [0,1,2,3]
)

dataframe2 = pd.DataFrame(
    {
        "A":["A4","A5","A6","A7"],
        "B":["B4","B5","B6","B7"],
        "C":["C4","C5","C6","C7"],
        "D":["D4","D5","D6","D7"]
    },
    index = [4,5,6,7]
)

dataframe3 = pd.DataFrame(
    {
        "A":["A8","A9","A10","A11"],
        "B":["B8","B9","B10","B11"],
        "C":["C8","C9","C10","C11"],
        "D":["D8","D9","D10","D11"]
    },
    index = [8,9,10,11]
)

# %%
all = [dataframe1,dataframe2,dataframe3]

# %%
all1 = pd.concat(all)

# %%
all1
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
dataframe4 = pd.DataFrame(
    {
        "B":["B2","B3","B6","B7"],
        "D":["D2","D3","D6","D7"],
        "F":["F2","F3","F6","F7"]
    },
    index=[2,3,6,7]
)

# %%
all2  = pd.concat([dataframe1,dataframe4],axis = 1)

# %%
all2
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
x1 = df[["Age","Name"]]

# %%
type(x1)
# Out:
# pandas.core.frame.DataFrame

# %%
x1.shape
# Out:
# (891, 2)

# %%
above_35 = df[df["Age"]> 35]

# %%
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...
